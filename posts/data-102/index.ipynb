# %% [raw]
# ---
# title: "[VDP] Aula 02 - Google Colab"
# author: "Walter R. Paixão-Côrtes"
# date: "2023-02-04"
# categories: [Visualização, Notebooks, Jupyter]
# image: colab.png
# toc: true
# description: Conhecendo nossa ferramenta de trabalho...
# ---

# %% [markdown]
# ### Introdução

# %% [markdown]
# Olá Cientista de Dados!
#
# Nesta aula vamos conhecer o Google Colab, e entender como utiliza-lo em nossas tarefas de Análise e Visualização de Dados.
#
# Vamos lá?

# %% [markdown]
# ### O que é o Google Colab?

# %% [markdown]
# O Google Colab é uma plataforma de computação em nuvem gratuita baseada no [Jupyter Notebook](https://jupyter.org/). Ele permite que os usuários criem e compartilhem documentos que contenham código executável, equações, visualizações e texto explicativo. O Google Colab oferece suporte a várias linguagens de programação populares, incluindo Python, JavaScript e Swift.
#
# Isto significa que podemos intercalar blocos de texto, imagens e código em um mesmo documento. Como um Cientista de Dados, você vai utilizar muito este recurso tanto nos momentos em que você está trabalhando os dados e construindo o modelo quanto naquele momento em que você precisa comunicar seus achados e resultados para outros cientistas e para o seu público alvo.

# %% [markdown]
# ### Como acessamos o Google Colab?

# %% [markdown]
# Para acessar o Google Colab, você precisa se conectar com uma conta do Google e acessar o site [colab.research.google.com](https://colab.research.google.com). Você verá então, a seguinte tela:

# %% [markdown]
# ![Tela Inicial do Colab](colab-001.png)

# %% [markdown]
# Como você pode ver, a primeira atividade que ele sugere é abrir exemplos ou, no meu caso, alguns arquivos mais recentes. O Colab é integrado com o Google Drive, então seus arquivos, que terão sempre a extensão `.ipynb` estarão sempre salvos lá no seu Drive, em uma pasta específica.

# %% [markdown]
# ### Iniciando um novo notebook!

# %% [markdown]
# Vamos iniciar? Clique no link "new notebook". Você deve ver sua tela assim:

# %% [markdown]
# ![Novo Notebook](colab-002.png)

# %% [markdown]
# Neste momento, vamos destacar três áreas da tela:
#
# 1) Onde fica o nome do notebook. Você pode modificar quando quiser
# 2) Sistema de arquivos do notebook. Quando iniciamos um novo notebook, temos um sistema de arquivos virtual, onde podemos subir arquivos que serão utilizados durante a execução do código. Esses arquivos são apagados quando o notebook não está ativo.
# 3) Esta é uma célula. Um notebook é feito de um conjunto de células que são executadas sequencialmente. As células podem ser de dois tipos: células de código ou células de texto. A célula que estamos marcando é especificamente uma célula de código, pois tem o botão de execução bem a esquerda.

# %% [markdown]
# #### Células de Texto

# %% [markdown]
# As células de texto nos permitem escrever texto no formato Markdown, que facilita bastante a formatação. Se quiser aprender mais sobre Markdown, [clique aqui](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). Veja alguns exemplos:

# %% [markdown]
# ![Exemplos de célula de texto](colab-003.png)

# %% [markdown]
# #### Células de Código

# %% [markdown]
# Células de código, como o próprio nome diz, servem para escrever código que será executado. Podemos usar algumas linguagens, sendo que a mais comum é Python. Cada célula, ao ser executada, pode imprimir o resultado de sua execução logo abaixo. Veja um exemplo abaixo:

# %%
import pandas as pd
import json
import requests

response = requests.get("https://dummyjson.com/products")
json.dump(json.loads(response.text)['products'], open('products.json','w'))
raw_data = open('products.json','r')
# .load("https://dummyjson.com/products")
df = pd.read_json(raw_data)

df
# Out:
#     id                                   title  \
# 0    1                                iPhone 9
# 1    2                                iPhone X
# 2    3                      Samsung Universe 9
# 3    4                                 OPPOF19
# 4    5                              Huawei P30
# 5    6                             MacBook Pro
# 6    7                     Samsung Galaxy Book
# 7    8              Microsoft Surface Laptop 4
# 8    9                          Infinix INBOOK
# 9   10                 HP Pavilion 15-DK1056WM
# 10  11                             perfume Oil
# 11  12                           Brown Perfume
# 12  13              Fog Scent Xpressio Perfume
# 13  14  Non-Alcoholic Concentrated Perfume Oil
# 14  15                    Eau De Perfume Spray
# 15  16                   Hyaluronic Acid Serum
# 16  17                           Tree Oil 30ml
# 17  18              Oil Free Moisturizer 100ml
# 18  19                      Skin Beauty Serum.
# 19  20           Freckle Treatment Cream- 15gm
# 20  21                 - Daal Masoor 500 grams
# 21  22                 Elbow Macaroni - 400 gm
# 22  23              Orange Essence Food Flavou
# 23  24               cereals muesli fruit nuts
# 24  25                    Gulab Powder 50 Gram
# 25  26                   Plant Hanger For Home
# 26  27                      Flying Wooden Bird
# 27  28               3D Embellishment Art Lamp
# 28  29                 Handcraft Chinese style
# 29  30                              Key Holder
#
#                                           description  price  \
# 0         An apple mobile which is nothing like apple    549
# 1   SIM-Free, Model A19211 6.5-inch Super Retina H...    899
# 2   Samsung's new variant which goes beyond Galaxy...   1249
# 3     OPPO F19 is officially announced on April 2021.    280
# 4   Huawei’s re-badged P30 Pro New Edition was off...    499
# 5   MacBook Pro 2021 with mini-LED display may lau...   1749
# 6   Samsung Galaxy Book S (2020) Laptop With Intel...   1499
# 7   Style and speed. Stand out on HD video calls b...   1499
# 8   Infinix Inbook X1 Ci3 10th 8GB 256GB 14 Win10 ...   1099
# 9   HP Pavilion 15-DK1056WM Gaming Laptop 10th Gen...   1099
# 10  Mega Discount, Impression of Acqua Di Gio by G...     13
# 11  Royal_Mirage Sport Brown Perfume for Men & Wom...     40
# 12  Product details of Best Fog Scent Xpressio Per...     13
# 13  Original Al Munakh® by Mahal Al Musk | Our Imp...    120
# 14  Genuine  Al-Rehab spray perfume from UAE/Saudi...     30
# 15  L'OrÃ©al Paris introduces Hyaluron Expert Repl...     19
# 16  Tea tree oil contains a number of compounds, i...     12
# 17  Dermive Oil Free Moisturizer with SPF 20 is sp...     40
# 18  Product name: rorec collagen hyaluronic acid w...     46
# 19  Fair & Clear is Pakistan's only pure Freckle c...     70
# 20  Fine quality Branded Product Keep in a cool an...     20
# 21  Product details of Bake Parlor Big Elbow Macar...     14
# 22  Specifications of Orange Essence Food Flavour ...     14
# 23  original fauji cereal muesli 250gm box pack or...     46
# 24  Dry Rose Flower Powder Gulab Powder 50 Gram • ...     70
# 25  Boho Decor Plant Hanger For Home Wall Decorati...     41
# 26  Package Include 6 Birds with Adhesive Tape Sha...     51
# 27  3D led lamp sticker Wall sticker 3d wall art l...     20
# 28  Handcraft Chinese style art luxury palace hote...     60
# 29  Attractive DesignMetallic materialFour key hoo...     30
#
#     discountPercentage  rating  stock                       brand  \
# 0                12.96    4.69     94                       Apple
# 1                17.94    4.44     34                       Apple
# 2                15.46    4.09     36                     Samsung
# 3                17.91    4.30    123                        OPPO
# 4                10.58    4.09     32                      Huawei
# 5                11.02    4.57     83                       Apple
# 6                 4.15    4.25     50                     Samsung
# 7                10.23    4.43     68           Microsoft Surface
# 8                11.83    4.54     96                     Infinix
# 9                 6.18    4.43     89                 HP Pavilion
# 10                8.40    4.26     65  Impression of Acqua Di Gio
# 11               15.66    4.00     52                Royal_Mirage
# 12                8.14    4.59     61          Fog Scent Xpressio
# 13               15.60    4.21    114                   Al Munakh
# 14               10.99    4.70    105             Lord - Al-Rehab
# 15               13.31    4.83    110               L'Oreal Paris
# 16                4.09    4.52     78                  Hemani Tea
# 17               13.10    4.56     88                     Dermive
# 18               10.68    4.42     54            ROREC White Rice
# 19               16.99    4.06    140                Fair & Clear
# 20                4.81    4.44    133                Saaf & Khaas
# 21               15.58    4.57    146             Bake Parlor Big
# 22                8.04    4.85     26           Baking Food Items
# 23               16.80    4.94    113                       fauji
# 24               13.58    4.87     47                    Dry Rose
# 25               17.86    4.08    131                  Boho Decor
# 26               15.58    4.41     17               Flying Wooden
# 27               16.49    4.82     54                  LED Lights
# 28               15.34    4.44      7               luxury palace
# 29                2.92    4.92     54                      Golden
#
#            category                                          thumbnail  \
# 0       smartphones  https://i.dummyjson.com/data/products/1/thumbn...
# 1       smartphones  https://i.dummyjson.com/data/products/2/thumbn...
# 2       smartphones  https://i.dummyjson.com/data/products/3/thumbn...
# 3       smartphones  https://i.dummyjson.com/data/products/4/thumbn...
# 4       smartphones  https://i.dummyjson.com/data/products/5/thumbn...
# 5           laptops  https://i.dummyjson.com/data/products/6/thumbn...
# 6           laptops  https://i.dummyjson.com/data/products/7/thumbn...
# 7           laptops  https://i.dummyjson.com/data/products/8/thumbn...
# 8           laptops  https://i.dummyjson.com/data/products/9/thumbn...
# 9           laptops  https://i.dummyjson.com/data/products/10/thumb...
# 10       fragrances  https://i.dummyjson.com/data/products/11/thumb...
# 11       fragrances  https://i.dummyjson.com/data/products/12/thumb...
# 12       fragrances  https://i.dummyjson.com/data/products/13/thumb...
# 13       fragrances  https://i.dummyjson.com/data/products/14/thumb...
# 14       fragrances  https://i.dummyjson.com/data/products/15/thumb...
# 15         skincare  https://i.dummyjson.com/data/products/16/thumb...
# 16         skincare  https://i.dummyjson.com/data/products/17/thumb...
# 17         skincare  https://i.dummyjson.com/data/products/18/thumb...
# 18         skincare  https://i.dummyjson.com/data/products/19/thumb...
# 19         skincare  https://i.dummyjson.com/data/products/20/thumb...
# 20        groceries  https://i.dummyjson.com/data/products/21/thumb...
# 21        groceries  https://i.dummyjson.com/data/products/22/thumb...
# 22        groceries  https://i.dummyjson.com/data/products/23/thumb...
# 23        groceries  https://i.dummyjson.com/data/products/24/thumb...
# 24        groceries  https://i.dummyjson.com/data/products/25/thumb...
# 25  home-decoration  https://i.dummyjson.com/data/products/26/thumb...
# 26  home-decoration  https://i.dummyjson.com/data/products/27/thumb...
# 27  home-decoration  https://i.dummyjson.com/data/products/28/thumb...
# 28  home-decoration  https://i.dummyjson.com/data/products/29/thumb...
# 29  home-decoration  https://i.dummyjson.com/data/products/30/thumb...
#
#                                                images
# 0   [https://i.dummyjson.com/data/products/1/1.jpg...
# 1   [https://i.dummyjson.com/data/products/2/1.jpg...
# 2     [https://i.dummyjson.com/data/products/3/1.jpg]
# 3   [https://i.dummyjson.com/data/products/4/1.jpg...
# 4   [https://i.dummyjson.com/data/products/5/1.jpg...
# 5   [https://i.dummyjson.com/data/products/6/1.png...
# 6   [https://i.dummyjson.com/data/products/7/1.jpg...
# 7   [https://i.dummyjson.com/data/products/8/1.jpg...
# 8   [https://i.dummyjson.com/data/products/9/1.jpg...
# 9   [https://i.dummyjson.com/data/products/10/1.jp...
# 10  [https://i.dummyjson.com/data/products/11/1.jp...
# 11  [https://i.dummyjson.com/data/products/12/1.jp...
# 12  [https://i.dummyjson.com/data/products/13/1.jp...
# 13  [https://i.dummyjson.com/data/products/14/1.jp...
# 14  [https://i.dummyjson.com/data/products/15/1.jp...
# 15  [https://i.dummyjson.com/data/products/16/1.pn...
# 16  [https://i.dummyjson.com/data/products/17/1.jp...
# 17  [https://i.dummyjson.com/data/products/18/1.jp...
# 18  [https://i.dummyjson.com/data/products/19/1.jp...
# 19  [https://i.dummyjson.com/data/products/20/1.jp...
# 20  [https://i.dummyjson.com/data/products/21/1.pn...
# 21  [https://i.dummyjson.com/data/products/22/1.jp...
# 22  [https://i.dummyjson.com/data/products/23/1.jp...
# 23  [https://i.dummyjson.com/data/products/24/1.jp...
# 24  [https://i.dummyjson.com/data/products/25/1.pn...
# 25  [https://i.dummyjson.com/data/products/26/1.jp...
# 26  [https://i.dummyjson.com/data/products/27/1.jp...
# 27  [https://i.dummyjson.com/data/products/28/1.jp...
# 28  [https://i.dummyjson.com/data/products/29/1.jp...
# 29  [https://i.dummyjson.com/data/products/30/1.jp...

# %% [markdown]
# Esta célula, se executada, irá carregar dados de um site, salvar um arquivo e carrega-lo em um DataFrame que depois será impresso na área de resultados.

# %% [markdown]
# ### Utilizando um notebook

# %% [markdown]
# Os exemplos acima são bons para mostrar cada parte separadamente, mas vamos a um exemplo que irá ilustrar a utilização típica destes blocos.
#
# #### Exemplo
#
# Digamos que você precisa entregar um relatório para o professor sobre quais são os primeiros 1000 números primos. Ele também solicita que você explique o que são números primos e como descobrir se um número é primo ou não.
#
# Em um cenário tradicional de programação, provavelmente se faria a entrega de pelo menos dois arquivos: um documento do word, por exemplo, com a parte descritiva e um arquivo de código-fonte com o código. Como o arquivo de código-fonte não guarda o resultado da execução, é muito provável que este resultado fosse adicionado ao documento do word, ou quem sabe, disponibilizado em um terceiro arquivo.
#
# Dá um certo trabalho preparar tudo... Além precisar de um computador com Word e com um editor de código-fonte para fazer todo o relatório. Mas com o Google Colab, você pode fazer tudo em um único lugar: um notebook pode ser editado de qualquer lugar, através do browser!
#
# Veja o resultado abaixo:

# %% [markdown]
# ![Notebook completo](colab-004.png)

# %% [markdown]
# É bem interessante, não é mesmo? Tudo em um único documento, que eu posso compartilhar com outras pessoas, sem nenhuma complicação. E o melhor, quem abre este notebook, pode executar as partes que são código, quando bem quiserem, sem depender de você para atualizar os resultados.

# %% [markdown]
# ### Finalizando

# %% [markdown]
# Espero que você tenha gostado de aprender um pouco sobre o ambiente de desenvolvimento que iremos utilizar neste curso. Ao longo do curso, utilizaremos recursos mais avançados, então não perca a oportunidade de aprender mais sobre o Google Colab com estes links abaixo:
#
# - [O que é Google Colab](https://www.alura.com.br/artigos/google-colab-o-que-e-e-como-usar?gclid=CjwKCAiAxvGfBhB-EiwAMPakqjBnFPSyZyay7wg-cefz02KTf52hSDkUZ-sUAXtIgv6x79w8AKjrghoCSAYQAvD_BwE)
# - [Google Colaboratory - Hashtag Treinamentos](https://www.hashtagtreinamentos.com/programar-online-google-colab-python)
# - [Vantagens de usar o Google Colab](https://kenzie.com.br/blog/google-colab/)

# %% [markdown]
# :::{.callout-note}
# Os artigos citado acima e o conteúdo apresentado nesta aula não são de maneira nenhuma uma revisão extensiva do Google Colab, apresentamos apenas o necessário para você andar com seus próprios pés e no seu ritmo!
# :::

# %% [markdown]
# ### Navegação
#
# | [< Anterior](/posts/data-101/index.html) 	| \| | [Próximo >](/posts/data-103/index.html) 	|
# |---------- |---|--------:	|
